# %%
import pandas as pd
from kabu import curves
from kabuWaves import waves
from kabuPeaksValleys import peaksValleys

# %%
configFile= pd.read_csv("/Users/linaruiz/Documents/projectEpidemicCurve/kabu/Kabu/ConfigFile.csv")
configFile
# Out:
#               Country Code  kernel1  kernel2
# 0             Belgium   BE       18       27
# 1             Bolivia   BO       18       27
# 2              Brazil   BR       50       27
# 3            Colombia   CO       35       27
# 4          Costa Rica   CR       25       27
# 5                Iran   IR       29       27
# 6               Italy   IT       29       27
# 7          Luxembourg   LU       29       27
# 8              Norway   NO       30       29
# 9   Republic of Korea   KR       20       29
# 10            Romania   RO       20       29
# 11     United Kingdom   GB       27       29
# 12      United States   US       31       29
# 13             Bosnia   BA       30       27
# 14            Croatia   HR       20       27
# 15            Ireland   IE       18       27
# 16              Spain   ES       30       27
# 17            Turkiye   TR       27       27

# %%
kernel0 = configFile[configFile["Code"]=="IT"]["kernel1"]
kernel = int(kernel0)

# %%
database= pd.read_csv("/Users/linaruiz/Documents/projectEpidemicCurve/data/database.csv")
datesName = "Date_reported"
casesName = "New_cases"
#kernel = 29
thresholdW = 2.5*10**-5
thresholdPV = -2.5*10**-5
plotName = "Peaks and Valleys for Italy k=18"
outFolder = "/Users/linaruiz/Documents/projectEpidemicCurve/kabu/Kabu/plots/"

#for peaksValleys class
test = peaksValleys(database,datesName,casesName,kernel,plotName,outFolder,thresholdPV)
g = test.run()  
g

# %%
database
# Out:
#      Unnamed: 0 Date_reported  New_cases
# 0             0    2020-01-03          0
# 1             1    2020-01-04          0
# 2             2    2020-01-05          0
# 3             3    2020-01-06          0
# 4             4    2020-01-07          0
# ..          ...           ...        ...
# 994         994    2022-09-23      22523
# 995         995    2022-09-24      21083
# 996         996    2022-09-25      22360
# 997         997    2022-09-26      18794
# 998         998    2022-09-27      10006
#
# [999 rows x 3 columns]
